# %%
given_str = 'aaa bbb ccc eee fff'
print (given_str.split(' ')[::2])
# Out:
# ['aaa', 'ccc', 'fff']

# %%
given_list = [1, 2, 3, 4, 5, 6]
for k, v in zip(given_list[::2], given_list[1::2]):
    print ([k, v])
# Out:
# [1, 2]
# [3, 4]
# [5, 6]

# %%
given_list = [1, 2, 3, 4, 5, 6]
#from itertools import chain
# print (list(chain.from_iterable([v, k] for k, v in zip(given_list[::2], given_list[1::2]))))
given_list[::2], given_list[1::2] = given_list[1::2], given_list[::2]
print (given_list)
# Out:
# [2, 1, 4, 3, 6, 5]

# %%
given_str = '1 22 333 4444 22 5555 1'

print (' '.join([substr for substr in given_str.split() if not len(substr) > 3]))
# Out:
# 1 22 333 22 1

# %%
given_num = 35142
print (int("".join(sorted([c for c in str(given_num)]))))
# Out:
# 12345

# %%
from itertools import chain
given_list = [123, 456, 789]

print (list(chain.from_iterable(str(x) for x in given_list)))
# Out:
# ['1', '2', '3', '4', '5', '6', '7', '8', '9']

# %%
given_num = 123456
result = 0
while given_num > 0:
    result += given_num % 100
    given_num = given_num // 100
print (result)
# Out:
# 102

# %%
# '-1-2-3-4-5-'
print (f"-{'-'.join([str(x) for x in range(1,1+5)])}-")
# Out:
# -1-2-3-4-5-

# %%
given_str = '1234567'

parts = [given_str[::-1][i:i+3][::-1] for i in range(0, len(given_str), 3)]
print (' '.join(parts[::-1]))
# Out:
# 1 234 567

# %%
given_list = [1, 2, 3, 3, 4, 5]

results = [given_list[i] == given_list[i+1] for i in range(len(given_list) - 1)]
print (any(results))

if len(given_list) == len(set(given_list)):
    print ("False")
else:
    print ("True")
# Out:
# True
# True
