# %%
given_str = 'abcdeabc'
print (sorted(set(given_str)))
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %%
given_dict = {
	'a': 1,
	'b': 2,
	'c': 3, 
	'd': 4,
}
print (list(given_dict.values()))
# Out:
# [1, 2, 3, 4]

# %%
given_dict = {
	'a': 1,
	'b': 2,
	'c': 3, 
	'd': 4,
}
print (set(given_dict.values()))
# Out:
# {1, 2, 3, 4}

# %%
given_str = '2025-12-31'
print (tuple(given_str.split('-')[::-1]))
# Out:
# ('31', '12', '2025')

# %%
given_list = ['2025', '12', '31']
print (tuple(given_list[::-1]))
# Out:
# ('31', '12', '2025')

# %%
given_str = 'aaa bbb ccc eee fff'
words = given_str.split()
words[1::2] = [w.capitalize() for w in words[1::2]]
' '.join(words)
# Out:
# 'aaa Bbb ccc Eee fff'

# %%
given_tuple = ('2025', '12', '31')
my_dict = { 'year': given_tuple[0], 'month': given_tuple[1], 'day': given_tuple[2]}
print (my_dict)
# Out:
# {'year': '2025', 'month': '12', 'day': '31'}

# %%
given_list = ['1', '2', '3', '4', '5']
print ([int(x) for x in given_list])
# Out:
# [1, 2, 3, 4, 5]

# %%
txt1 = 'abcde'
txt2 = '12345'

my_dict = {char: int(num) for char, num in zip(txt1, txt2)}

print (my_dict)
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4, 'e': 5}

# %%
given_list = ['1', '2', '3', '4', '5']
print (sum([int(x) for x in given_list]))
# Out:
# 15
