# %%
import sys

first_word=input()
second_word=input()

if len(first_word) == 0 or len(second_word) == 0:
    print("False")
elif first_word[0] == second_word[0]:
    print("True")
else:
    print("False")

# %%
given_list = [1, 2, 3, 4, 5, 6]
print (given_list[0:3])
# Out:
# [1, 2, 3]

# %%
date_dict = {
	'year' : '2025',
	'month': '12',
	'day'  : '31',
}

print ('-'.join(date_dict.values()))
# Out:
# 2025-12-31

# %%
given_str = 'abcdeabc'
print (sorted(set(given_str)))
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %%
given_list = [1, 2, 3, 4, 5, 6]
print (given_list[::2])
# Out:
# [1, 3, 5]

# %%
given_str = 'abcde'
print(*given_str[::-1])
# Out:
# e d c b a

# %%
given_num = 12345
digits = [int(digit) for digit in str(given_num)]
print (sum(digits))
# Out:
# 15

# %%
given_str = 'abcdef'
print (given_str[:3])
# Out:
# abc

# %%
given_dict = {
	'a': 1,
	'b': 2,
	'c': 3, 
	'd': 4,
}

for key, value in given_dict.items():
    given_dict[key] = value*2

print (given_dict)
# Out:
# {'a': 2, 'b': 4, 'c': 6, 'd': 8}

# %%
given_num = 12345
print(*str(given_num)[::-1])
# Out:
# 5 4 3 2 1
