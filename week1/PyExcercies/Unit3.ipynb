# %%
given_list = [1, 2, 3, 4, 5, 6]
print (sum(given_list[:len(given_list)//2]))
# Out:
# 6

# %%
given_list = [1, 2, 3, 4, 5, 6]
first_half_sum = sum(given_list[:len(given_list)//2])
second_half_sum = sum(given_list[len(given_list)//2:])
print (first_half_sum / second_half_sum)
# Out:
# 0.4

# %%
st1 = {1, 2, 3}
st2 = {4, 5, 6}

print (st1 | st2)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
st1 = {1, 2, 3, 4, 5}
st2 = {4, 5, 6, 7, 8}

print (st1 ^ st2)
# Out:
# {1, 2, 3, 6, 7, 8}

# %%
num = 5;
print("0" * num)
# Out:
# 00000

# %%
lst1 = [1, 2, 3, 4, 5]
lst2 = [1, 2, 3]
for elem in lst1:
    if elem in lst2:
        pass
    else:
        print ("NO")
        break
else:
    print ("YES")
# Out:
# NO

# %%
given_str = 'a bc def ghij'
print (' '.join([w.upper() if len(w) <=3 else w for w in given_str.split()]))
# Out:
# A BC DEF ghij

# %%
given_str = 'camelCase'
print ("".join(['_' + c.lower() if c.isupper() else c for c in given_str]))
# Out:
# camel_case

# %%
lst1 = [1, 2, 3]
lst2 = [4, 5, 6]

for elem in zip(lst1,lst2):
    print(elem)
# Out:
# (1, 4)
# (2, 5)
# (3, 6)

# %%
given_list = [123, 456, 789]
print ([int(str(num)[::-1]) for num in given_list])
# Out:
# [321, 654, 987]
